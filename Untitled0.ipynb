# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import statistics as sts

# %%
base = pd.read_csv('dados.csv', sep = ";")
print(base.to_string())

# %%
base.isnull().sum()
#Não tem nulos
# Out:
# CODIGO          0
# MUNICIPIO       0
# PIB             0
# VALOREMPENHO    0
# dtype: int64

# %%
base.duplicated().sum()
#duplicatas
# Out:
# 0

# %%
base[base.duplicated(['CODIGO'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [CODIGO, MUNICIPIO, PIB, VALOREMPENHO]
# Index: []

# %%
base.drop_duplicates(subset = "CODIGO", keep = 'first', inplace = True)
base[base.duplicated(['CODIGO'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [CODIGO, MUNICIPIO, PIB, VALOREMPENHO]
# Index: []

# %%
base.describe()
# Out:
#            CODIGO            PIB  VALOREMPENHO
# count  187.000000     187.000000  1.870000e+02
# mean   247.155080   19808.741337  1.299844e+05
# std    138.750385   16984.223244  1.615491e+05
# min      1.000000    8236.630000  1.721300e+02
# 25%    141.000000   13621.455000  5.251718e+04
# 50%    242.000000   17206.190000  8.422816e+04
# 75%    372.500000   21429.165000  1.538961e+05
# max    496.000000  223848.220000  1.442760e+06

# %%
sb.boxplot(data = base)
#tem alguns fora do comum que eu vou checar dps
# Out:
# <Axes: >

# %%
base["VALOREMPENHO"].min()
#1442759.82 <- max
#172.13 <- min
# Out:
# 172.13

# %%
maiorEmpenho = base.loc[(base['VALOREMPENHO'] == 1442759.82)]
maiorEmpenho
# Out:
#     CODIGO MUNICIPIO        PIB  VALOREMPENHO
# 49     149   TRIUNFO  223848.22    1442759.82

# %%
menorEmpenho = base.loc[(base['VALOREMPENHO'] == 172.13)]
menorEmpenho
# Out:
#      CODIGO            MUNICIPIO       PIB  VALOREMPENHO
# 186      60  GUARANI DAS MISSOES  24363.31        172.13

# %%
base.sort_values(by='VALOREMPENHO', ascending=False)

#Tabela ordenada pelo valor do VALOREMPENHO
# Out:
#      CODIGO                MUNICIPIO        PIB  VALOREMPENHO
# 49      149                  TRIUNFO  223848.22    1442759.82
# 0       106    SANTANA DO LIVRAMENTO   12240.76    1088666.10
# 1       113             SANTO ANGELO   16575.82     800669.92
# 4       120              SAO GABRIEL   19912.38     533719.86
# 3        13          CACAPAVA DO SUL   13674.54     485535.86
# ..      ...                      ...        ...           ...
# 182     372  SANTA VITORIA DO PALMAR   27170.89        760.00
# 183     107     SANTA BARBARA DO SUL   29654.02        365.00
# 185     382          NOVA SANTA RITA   25938.38        310.58
# 184      54           GETULIO VARGAS   16876.33        233.01
# 186      60      GUARANI DAS MISSOES   24363.31        172.13
#
# [187 rows x 4 columns]

# %%
base["PIB"].max()
base["PIB"].min()
#223848.22 <- max
#8236.63 <- min
# Out:
# 8236.63

# %%
maiorPIB = base.loc[(base['PIB'] == 223848.22)]
maiorPIB
# Out:
#     CODIGO MUNICIPIO        PIB  VALOREMPENHO
# 49     149   TRIUNFO  223848.22    1442759.82

# %%
menorPIB = base.loc[(base['PIB'] == 8236.63)]
menorPIB
# Out:
#     CODIGO  MUNICIPIO      PIB  VALOREMPENHO
# 88     216  REDENTORA  8236.63       60134.0

# %%
base.sort_values(by='PIB', ascending=False)

#Tabela ordenada pelo valor do PIB
# Out:
#      CODIGO            MUNICIPIO        PIB  VALOREMPENHO
# 49      149              TRIUNFO  223848.22    1442759.82
# 146     453        MUITOS CAPOES   72353.72     140597.55
# 91      356            GARRUCHOS   68672.25     271841.26
# 176     108    SANTA CRUZ DO SUL   40671.53       9637.00
# 155     476        CAPAO DO CIPO   36739.78      60851.00
# ..      ...                  ...        ...           ...
# 89      413   SAO VALERIO DO SUL   10503.72      67638.25
# 66      414     SENTINELA DO SUL   10477.52      92380.20
# 15       38  ENCRUZILHADA DO SUL   10372.80     200738.61
# 11      248      AMARAL FERRADOR    9216.87     235327.02
# 88      216            REDENTORA    8236.63      60134.00
#
# [172 rows x 4 columns]

# %%
base['CODIGO'].duplicated().sum()
# Out:
# 15

# %%
sb.histplot(data = base['PIB'], kde = False).set(title = "PIB")
# Out:
# [Text(0.5, 1.0, 'PIB')]

# %%
sb.histplot(data = base['VALOREMPENHO'], kde = False).set(title = "Valor Empenho")
# Out:
# [Text(0.5, 1.0, 'Valor Empenho')]

# %%
agrupamentoValorDesempenho = base.sort_values(by='VALOREMPENHO', ascending=False)
agrupamentoValorDesempenho = agrupamentoValorDesempenho.head(10)[['VALOREMPENHO', "MUNICIPIO"]]
agrupamentoValorDesempenho
# Out:
#     VALOREMPENHO               MUNICIPIO
# 49    1442759.82                 TRIUNFO
# 0     1088666.10   SANTANA DO LIVRAMENTO
# 1      800669.92            SANTO ANGELO
# 4      533719.86             SAO GABRIEL
# 3      485535.86         CACAPAVA DO SUL
# 2      466122.80  SAO FRANCISCO DE ASSIS
# 9      401124.62              URUGUAIANA
# 8      385185.68        SAO LUIZ GONZAGA
# 5      381286.24                  QUARAI
# 10     371857.25             DOM PEDRITO

# %%
sb.barplot(x='MUNICIPIO', y='VALOREMPENHO', data = agrupamentoValorDesempenho)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
agrupamentoValorPIB = base.sort_values(by='PIB', ascending=False)
agrupamentoValorPIB = agrupamentoValorPIB.head(10)[['PIB', 'MUNICIPIO']]

agrupamentoValorPIB
# Out:
#            PIB          MUNICIPIO
# 49   223848.22            TRIUNFO
# 146   72353.72      MUITOS CAPOES
# 91    68672.25          GARRUCHOS
# 176   40671.53  SANTA CRUZ DO SUL
# 155   36739.78      CAPAO DO CIPO
# 68    34568.53              MARAU
# 145   33730.13           GLORINHA
# 169   31104.22         VILA MARIA
# 175   30524.80       PORTO ALEGRE
# 106   30468.92  EUGENIO DE CASTRO

# %%
sb.barplot(x='MUNICIPIO', y='PIB', data = agrupamentoValorPIB)
plt.xticks(rotation=45, ha='right')
plt.show()
